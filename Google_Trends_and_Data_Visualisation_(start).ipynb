# %% [markdown]
# <a href="https://colab.research.google.com/github/imaadfakier/google-search-trends/blob/main/Google_Trends_and_Data_Visualisation_(start).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# Google Trends gives us an estimate of search volume. Let's explore if search popularity relates to other kinds of data. Perhaps there are patterns in Google's search volume and the price of Bitcoin or a hot stock like Tesla. Perhaps search volume for the term "Unemployment Benefits" can tell us something about the actual unemployment rate?
#
# Data Sources: <br>
# <ul>
# <li> <a href="https://fred.stlouisfed.org/series/UNRATE/">Unemployment Rate from FRED</a></li>
# <li> <a href="https://trends.google.com/trends/explore">Google Trends</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/TSLA/history?p=TSLA">Yahoo Finance for Tesla Stock Price</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/BTC-USD/history?p=BTC-USD">Yahoo Finance for Bitcoin Stock Price</a> </li>
# </ul>

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# # Read the Data
#
# Download and add the .csv files to the same folder as your notebook.

# %%
df_tesla = pd.read_csv('TESLA Search Trend vs Price.csv')
print(df_tesla)

df_btc_search = pd.read_csv('Bitcoin Search Trend.csv')
df_btc_price = pd.read_csv('Daily Bitcoin Price.csv')
print(df_btc_search, df_btc_price, sep='\n')

df_unemployment = pd.read_csv('UE Benefits Search vs UE Rate 2004-19.csv')
print(df_unemployment)
# Out:
#           MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0    2010-06-01                3        4.766000
# 1    2010-07-01                3        3.988000
# 2    2010-08-01                2        3.896000
# 3    2010-09-01                2        4.082000
# 4    2010-10-01                2        4.368000
# ..          ...              ...             ...
# 119  2020-05-01               16      167.000000
# 120  2020-06-01               17      215.962006
# 121  2020-07-01               24      286.152008
# 122  2020-08-01               23      498.320007
# 123  2020-09-01               31      407.339996
#
# [124 rows x 3 columns]
#       MONTH  BTC_NEWS_SEARCH
# 0   2014-09                5
# 1   2014-10                4
# 2   2014-11                4
# 3   2014-12                4
# 4   2015-01                5
# ..      ...              ...
# 68  2020-05               22
# 69  2020-06               13
# 70  2020-07               14
# 71  2020-08               16
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Tesla

# %% [markdown]
# **Challenge**: <br>
# <ul>
# <li>What are the shapes of the dataframes? [DONE]</li>
# <li>How many rows and columns? [DONE]</li>
# <li>What are the column names? [DONE]</li>
# <li>Complete the f-string to show the largest/smallest number in the search data column [DONE]</li>
# <li>Try the <code>.describe()</code> function to see some useful descriptive statistics [DONE]</li>
# <li>What is the periodicity of the time series data (daily, weekly, monthly)? [DONE]</li>
# <li>What does a value of 100 in the Google Trend search popularity actually mean? <em>(**ANSWER: We can see from our DataFrames that Google's search interest ranges between 0 and 100. But what does that mean? Google defines the values of search interest as:**
#
# **Numbers represent search interest relative to the highest point on the chart for the given region and time. A value of 100 is the peak popularity for the term. A value of 50 means that the term is half as popular. A score of 0 means there was not enough data for this term.**
#
# **Basically, the actual search volume of a term is not publicly available. Google only offers a scaled number. Each data point is divided by the total searches of the geography and time range it represents to compare relative popularity.**)</em> [DONE]</li>
# </ul>

# %%
df_tesla.shape
# Out:
# (124, 3)

# %%
df_tesla.columns
# Out:
# Index(['MONTH', 'TSLA_WEB_SEARCH', 'TSLA_USD_CLOSE'], dtype='object')

# %%
print(f'Largest value for Tesla in Web Search: {df_tesla["TSLA_WEB_SEARCH"].max()}')
# df_tesla['TSLA_WEB_SEARCH'].min()
print(f'Smallest value for Tesla in Web Search: {df_tesla["TSLA_WEB_SEARCH"].min()}')
# df_tesla['TSLA_WEB_SEARCH'].max()
# Out:
# Largest value for Tesla in Web Search: 31
# Smallest value for Tesla in Web Search: 2

# %%
df_tesla.describe()
# Out:
#        TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# count       124.000000      124.000000
# mean          8.725806       50.962145
# std           5.870332       65.908389
# min           2.000000        3.896000
# 25%           3.750000        7.352500
# 50%           8.000000       44.653000
# 75%          12.000000       58.991999
# max          31.000000      498.320007

# %%
# What is the periodicity of the time series data (daily, weekly, monthly)?
# monthly.

# %%
# What does a value of 100 in the Google Trend search popularity actually mean?

# %% [markdown]
# ### Unemployment Data

# %%
df_unemployment.shape
# Out:
# (181, 3)

# %%
df_unemployment.columns
# Out:
# Index(['MONTH', 'UE_BENEFITS_WEB_SEARCH', 'UNRATE'], dtype='object')

# %%
print('Largest value for "Unemployemnt Benefits" '
      f'in Web Search: {df_unemployment["UE_BENEFITS_WEB_SEARCH"].max()}')
# Out:
# Largest value for "Unemployemnt Benefits" in Web Search: 100

# %%
df_unemployment.describe()
# Out:
#        UE_BENEFITS_WEB_SEARCH      UNRATE
# count              181.000000  181.000000
# mean                35.110497    6.217680
# std                 20.484925    1.891859
# min                 14.000000    3.700000
# 25%                 21.000000    4.700000
# 50%                 26.000000    5.400000
# 75%                 45.000000    7.800000
# max                100.000000   10.000000

# %%
# What is the periodicity of the time series data (daily, weekly, monthly)?
# monthly.

# %%
# What does a value of 100 in the Google Trend search popularity actually mean?

# %% [markdown]
# ### Bitcoin

# %%
print(df_btc_search.shape)
print(df_btc_price.shape)
# Out:
# (73, 2)
# (2204, 3)

# %%
print(df_btc_search.columns)
print(df_btc_price.columns)
# Out:
# Index(['MONTH', 'BTC_NEWS_SEARCH'], dtype='object')
# Index(['DATE', 'CLOSE', 'VOLUME'], dtype='object')

# %%
print(f'largest BTC News Search: {df_btc_search["BTC_NEWS_SEARCH"].max()}')
# Out:
# largest BTC News Search: 100

# %%
print(df_btc_search.describe())
print(df_btc_price.describe())
# Out:
#        BTC_NEWS_SEARCH
# count        73.000000
# mean         15.013699
# std          15.146959
# min           3.000000
# 25%           5.000000
# 50%          14.000000
# 75%          18.000000
# max         100.000000
#               CLOSE        VOLUME
# count   2203.000000  2.203000e+03
# mean    4429.421245  8.043622e+09
# std     4148.150071  1.176529e+10
# min      178.102997  5.914570e+06
# 25%      433.629502  6.029915e+07
# 50%     3637.520020  2.018890e+09
# 75%     7997.372803  1.322478e+10
# max    19497.400391  7.415677e+10

# %%
# What is the periodicity of the time series data (daily, weekly, monthly)?
# monthly and daily.

# %%
# What does a value of 100 in the Google Trend search popularity actually mean?

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Check for Missing Values

# %% [markdown]
# **Challenge**: Are there any missing values in any of the dataframes? If so, which row/rows have missing values? How many missing values are there?

# %%
# Are there any missing values in any of the dataframes?

# print(f'Missing values for Tesla?: {df_tesla.isna().count().any()}')  # wrong!
# print(f'Missing values for U/E?: {df_unemployment.isna().count().any()}')  # wrong!
# print(f'Missing values for BTC Search?: {df_btc_search.isna().count().any()}')  # wrong!
print(f'Missing values for Tesla?: {df_tesla.isna().any()}')
print(f'Missing values for U/E?: {df_unemployment.isna().any()}')
print(f'Missing values for BTC Search?: {df_btc_search.isna().any()}')
# Out:
# Missing values for Tesla?: MONTH              False
# TSLA_WEB_SEARCH    False
# TSLA_USD_CLOSE     False
# dtype: bool
# Missing values for U/E?: MONTH                     False
# UE_BENEFITS_WEB_SEARCH    False
# UNRATE                    False
# dtype: bool
# Missing values for BTC Search?: MONTH              False
# BTC_NEWS_SEARCH    False
# dtype: bool

# %%
# Are there any missing values in any of the dataframes?
# print(f'Missing values for BTC price?: {df_btc_price.isna().count().any()}')  # wrong!
print(f'Missing values for BTC price?: {df_btc_price.isna().any()}')
print()
print(f'Missing values for BTC price?: {df_btc_price.isna().values.any()}')  # <--- learned something new
print('\n')

# If so, which row/rows have missing values?
# df_btc_price[df_btc_price['CLOSE'].isna()]
print(df_btc_price[df_btc_price['CLOSE'].isna()])
print()
print(df_btc_price[df_btc_price['VOLUME'].isna()])
print('\n')
print(f'Missing values for BTC price?: {df_btc_price[df_btc_price["CLOSE"].isna()]}')
print()
print(f'Missing values for BTC price?: {df_btc_price[df_btc_price["VOLUME"].isna()]}')
# Out:
# Missing values for BTC price?: DATE      False
# CLOSE      True
# VOLUME     True
# dtype: bool
#
# Missing values for BTC price?: True
#
#
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN
#
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN
#
#
# Missing values for BTC price?:             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN
#
# Missing values for BTC price?:             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %%
# How many missing values are there?
# print(f'Number of missing values: {df_tesla.isna().count().sum() + df_unemployment.isna().count().sum() + df_btc_search.isna().count().sum() + df_btc_price.isna().count().sum()}')
print(f'Number of missing values: {df_btc_price.isna().sum()}')
print(f'Number of missing values: {df_btc_price.isna().values.sum()}')  # <--- learned something new; this is what you were looking for.
# Out:
# Number of missing values: DATE      0
# CLOSE     1
# VOLUME    1
# dtype: int64
# Number of missing values: 2

# %% [markdown]
# **Challenge**: Remove any missing values that you found.

# %%
# print(df_tesla.dropna(), df_unemployment.dropna(), df_btc_search.dropna(), df_btc_price.dropna(), sep='\n')  # wrong!

# df_btc_price.dropna(inplace=True)
# To remove a missing value we can use .dropna(). The inplace argument allows to 
# overwrite our (already-)existing DataFrame and means we don't have to write:
# df_btc_price = df_btc_price.dropna()

# no_nans_df_btc_price = df_btc_price.dropna()
# no_nans_df_btc_price

df_btc_price.dropna(inplace=True)
df_btc_price
# print(df_btc_price)
# Out:
#             DATE         CLOSE        VOLUME
# 0     2014-09-17    457.334015  2.105680e+07
# 1     2014-09-18    424.440002  3.448320e+07
# 2     2014-09-19    394.795990  3.791970e+07
# 3     2014-09-20    408.903992  3.686360e+07
# 4     2014-09-21    398.821014  2.658010e+07
# ...          ...           ...           ...
# 2199  2020-09-24  10745.548828  2.301754e+10
# 2200  2020-09-25  10702.290039  2.123255e+10
# 2201  2020-09-26  10754.437500  1.810501e+10
# 2202  2020-09-27  10774.426758  1.801688e+10
# 2203  2020-09-28  10912.536133  2.122653e+10
#
# [2203 rows x 3 columns]

# %% [markdown]
# ### Convert Strings to DateTime Objects

# %% [markdown]
# **Challenge**: Check the data type of the entries in the DataFrame MONTH or DATE columns. Convert any strings into Datetime objects. Do this for all 4 DataFrames. Double check if your type conversion was successful.

# %%
# df_tesla['MONTH'][0]
# type(df_tesla['MONTH'][0])
print(
    type(df_tesla['MONTH'][0]), 
    df_tesla['MONTH'][0], 
    type(df_unemployment['MONTH'][1]), 
    df_unemployment['MONTH'][1], 
    type(df_btc_search['MONTH'][2]), 
    df_btc_search['MONTH'][2], 
    type(df_btc_price['DATE'][3]), 
    df_btc_price['DATE'][3], 
    sep='\n',
)
# Out:
# <class 'str'>
# 2010-06-01
# <class 'str'>
# 2004-02
# <class 'str'>
# 2014-11
# <class 'str'>
# 2014-09-20

# %%
print(pd.to_datetime(df_tesla['MONTH']))
print(pd.to_datetime(df_unemployment['MONTH']))
print(pd.to_datetime(df_btc_search['MONTH']))
print(pd.to_datetime(df_btc_price['DATE']))
# Out:
# 0     2010-06-01
# 1     2010-07-01
# 2     2010-08-01
# 3     2010-09-01
# 4     2010-10-01
#          ...
# 119   2020-05-01
# 120   2020-06-01
# 121   2020-07-01
# 122   2020-08-01
# 123   2020-09-01
# Name: MONTH, Length: 124, dtype: datetime64[ns]
# 0     2004-01-01
# 1     2004-02-01
# 2     2004-03-01
# 3     2004-04-01
# 4     2004-05-01
#          ...
# 176   2018-09-01
# 177   2018-10-01
# 178   2018-11-01
# 179   2018-12-01
# 180   2019-01-01
# Name: MONTH, Length: 181, dtype: datetime64[ns]
# 0    2014-09-01
# 1    2014-10-01
# 2    2014-11-01
# 3    2014-12-01
# 4    2015-01-01
#         ...
# 68   2020-05-01
# 69   2020-06-01
# 70   2020-07-01
# 71   2020-08-01
# 72   2020-09-01
# Name: MONTH, Length: 73, dtype: datetime64[ns]
# 0      2014-09-17
# 1      2014-09-18
# 2      2014-09-19
# 3      2014-09-20
# 4      2014-09-21
#           ...
# 2199   2020-09-24
# 2200   2020-09-25
# 2201   2020-09-26
# 2202   2020-09-27
# 2203   2020-09-28
# ...

# %%
df_tesla['MONTH'] = pd.to_datetime(df_tesla['MONTH'])
df_btc_search['MONTH'] = pd.to_datetime(df_btc_search['MONTH'])
df_unemployment['MONTH'] = pd.to_datetime(df_unemployment['MONTH'])
df_btc_price['DATE'] = pd.to_datetime(df_btc_price['DATE'])

print(
    df_tesla['MONTH'].head(),  # <--- learned something new
    df_unemployment['MONTH'].head(),  # " "
    df_btc_search['MONTH'].head(), # " "
    df_btc_price['DATE'].head(),  # " "
    sep='\n',
)
# Out:
# 0   2010-06-01
# 1   2010-07-01
# 2   2010-08-01
# 3   2010-09-01
# 4   2010-10-01
# Name: MONTH, dtype: datetime64[ns]
# 0   2004-01-01
# 1   2004-02-01
# 2   2004-03-01
# 3   2004-04-01
# 4   2004-05-01
# Name: MONTH, dtype: datetime64[ns]
# 0   2014-09-01
# 1   2014-10-01
# 2   2014-11-01
# 3   2014-12-01
# 4   2015-01-01
# Name: MONTH, dtype: datetime64[ns]
# 0   2014-09-17
# 1   2014-09-18
# 2   2014-09-19
# 3   2014-09-20
# 4   2014-09-21
# Name: DATE, dtype: datetime64[ns]

# %%
# All the date data in our columns are in the form of strings. To convert this 
# into a Datetime object we're going to use the Pandas .to_datetime() function.

# df_tesla.MONTH = pd.to_datetime(df_tesla.MONTH)
# df_btc_search.MONTH = pd.to_datetime(df_btc_search.MONTH)
# df_unemployment.MONTH = pd.to_datetime(df_unemployment.MONTH)
# df_btc_price.DATE = pd.to_datetime(df_btc_price.DATE)

# %% [markdown]
# ### Converting from Daily to Monthly Data
#
# [Pandas .resample() documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html) <br>

# %%
# Next, we have to think about how to make our Bitcoin price and our Bitcoin 
# search volume comparable. Our Bitcoin price is daily data, but our Bitcoin 
# Search Popularity is monthly data.

# To convert our daily data into monthly data, we're going to use the 
# .resample() function. The only things we need to specify is which column to 
# use (i.e., our DATE column) and what kind of sample frequency we want (i.e., 
# the "rule"). We want a monthly frequency, so we use 'M'.  If you ever need to 
# resample a time series to a different frequency, you can find a list of 
# different options here (for example 'Y' for yearly or 'T' for minute).

# After resampling, we need to figure out how the data should be treated. In our 
# case, we want the last available price of the month - the price at month-end.
df_btc_monthly = df_btc_price.resample('M', on='DATE').last()

# # If we wanted the average price over the course of the month, we could use 
# # something like:
# df_btc_monthly_average_price = df_btc_price.resample('M', on='DATE').mean()

# %%
# We have 73 rows in our price data - the same as our search data. Nice! 😎
df_btc_monthly.shape
# print(df_btc_monthly.shape, df_btc_search.shape, sep='\n')
print(df_btc_search.shape)
# Out:
# (73, 2)

# %%
# This is what our data looks like now:
df_btc_monthly.head()
# Out:
#                  DATE       CLOSE      VOLUME
# DATE
# 2014-09-30 2014-09-30  386.944000  34707300.0
# 2014-10-31 2014-10-31  338.321014  12545400.0
# 2014-11-30 2014-11-30  378.046997   9194440.0
# 2014-12-31 2014-12-31  320.192993  13942900.0
# 2015-01-31 2015-01-31  217.464005  23348200.0

# %%
df_btc_monthly.tail()
# Out:
#                  DATE         CLOSE        VOLUME
# DATE
# 2020-05-31 2020-05-31   9461.058594  2.777329e+10
# 2020-06-30 2020-06-30   9137.993164  1.573580e+10
# 2020-07-31 2020-07-31  11323.466797  2.316047e+10
# 2020-08-31 2020-08-31  11680.820313  2.228593e+10
# 2020-09-30 2020-09-28  10912.536133  2.122653e+10

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ### Notebook Formatting & Style Helpers

# %%
# Create locators for ticks on the time axis
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# %%
# # Register date converters to avoid warning messages
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# ### Tesla Stock Price v.s. Search Volume

# %% [markdown]
# **Challenge:** Plot the Tesla stock price against the Tesla search volume using a line chart and two different axes. Label one axis 'TSLA Stock Price' and the other 'Search Trend'.

# %%
ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'])
ax2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'])

ax1.set_ylabel('TSLA Stock Price')
ax2.set_ylabel('Search Trend')

plt.show()

# %% [markdown]
# **Challenge**: Add colours to style the chart. This will help differentiate the two lines and the axis labels. Try using one of the blue [colour names](https://matplotlib.org/3.1.1/gallery/color/named_colors.html) for the search volume and a HEX code for a red colour for the stock price.
# <br>
# <br>
# Hint: you can colour both the [axis labels](https://matplotlib.org/3.3.2/api/text_api.html#matplotlib.text.Text) and the [lines](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D) on the chart using keyword arguments (kwargs).

# %%
# plt.title('Tesla Web Search vs Price')
plt.figure(figsize=(14, 8), dpi=100)
plt.title('Tesla Web Search vs Price')  # <--- learned something new

plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
# ax1.set_title('Tesla Web Search vs Price')
ax2 = ax1.twinx()
# ax2.set_title('Tesla Web Search vs Price')

ax1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'], color='#C70039', linewidth=2)
ax2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'], color='c', linewidth=2)

# ax1.set_xlim()
ax1.set_ylabel('TSLA Stock Price', color='#C70039', fontsize=14)
# ax1.set_ylim()
# ax2.set_xlim()
ax2.set_ylabel('Search Trend', color='c', fontsize=14)
# ax2.set_ylim()

plt.show()

# %% [markdown]
# **Challenge**: Make the chart larger and easier to read.
# 1. Increase the figure size (e.g., to 14 by 8).
# 2. Increase the font sizes for the labels and the ticks on the x-axis to 14.
# 3. Rotate the text on the x-axis by 45 degrees.
# 4. Make the lines on the chart thicker.
# 5. Add a title that reads 'Tesla Web Search vs Price'
# 6. Keep the chart looking sharp by changing the dots-per-inch or [DPI value](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.figure.html).
# 7. Set minimum and maximum values for the y and x axis. Hint: check out methods like [set_xlim()](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.set_xlim.html).
# 8. Finally use [plt.show()](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.show.html) to display the chart below the cell instead of relying on the automatic notebook output.

# %%
# plt.title('Tesla Web Search vs Price')
plt.figure(figsize=(14, 8), dpi=100)
plt.title('Tesla Web Search vs Price')  # <--- learned something new

plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
# ax1.set_title('Tesla Web Search vs Price')
ax2 = ax1.twinx()
# ax2.set_title('Tesla Web Search vs Price')

ax1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'], color='#C70039', linewidth=2)
ax2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'], color='c', linewidth=2)

# With .set_ylim() and .set_xlim() you have precise control over which data you 
# want to show on the chart. You can either choose hard values like displaying 
# the Tesla stock price between $0 and $600. Or you could use the .min() and 
# .max() functions to help you work out the bounds for the chart as well.
# ax1.set_xlim([df_tesla.MONTH.min(), df_tesla.MONTH.max()])
ax1.set_xlim([df_tesla['MONTH'].min(), df_tesla['MONTH'].max()])
ax1.set_ylabel('TSLA Stock Price', color='#C70039', fontsize=14)
ax1.set_ylim([0, 600])
# ax2.set_xlim([df_tesla.['MONTH'].min(), df_tesla.['MONTH'].max()])
ax2.set_ylabel('Search Trend', color='c', fontsize=14)
# ax2.set_ylim()

plt.show()

# %% [markdown]
# How to add tick formatting for dates on the x-axis.

# %%
plt.figure(figsize=(14, 8), dpi=100)
plt.title('Tesla Web Search vs Price')

plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
ax2 = ax1.twinx()

# format the ticks
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'], color='#C70039', linewidth=2)
ax2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'], color='c', linewidth=2)

ax1.set_xlim([df_tesla['MONTH'].min(), df_tesla['MONTH'].max()])
ax1.set_ylabel('TSLA Stock Price', color='#C70039', fontsize=14)
ax1.set_ylim([0, 600])
# ax2.set_xlim([df_tesla.['MONTH'].min(), df_tesla.['MONTH'].max()])
ax2.set_ylabel('Search Trend', color='c', fontsize=14)

plt.show()

# %% [markdown]
# ### Bitcoin (BTC) Price v.s. Search Volume

# %% [markdown]
# **Challenge**: Create the same chart for the Bitcoin Prices vs. Search volumes. <br>
# 1. Modify the chart title to read 'Bitcoin News Search vs Resampled Price' <br>
# 2. Change the y-axis label to 'BTC Price' <br>
# 3. Change the y- and x-axis limits to improve the appearance <br>
# 4. Investigate the [linestyles](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html ) to make the BTC price a dashed line <br>
# 5. Investigate the [marker types](https://matplotlib.org/3.2.1/api/markers_api.html) to make the search datapoints little circles <br>
# 6. Were big increases in searches for Bitcoin accompanied by big increases in the price?

# %%
plt.figure(figsize=(14, 8), dpi=100)
plt.title('Bitcoin News Search vs Resampled Price')

plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
ax2 = ax1.twinx()

# format the ticks
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.plot(df_btc_monthly['DATE'], df_btc_monthly['CLOSE'], color='orange', linewidth=2, linestyle='--')
ax1.plot(df_btc_monthly['DATE'], df_btc_monthly['CLOSE'], color='#F08F2E', linewidth=2, linestyle='--')
# # ax2.plot(df_btc_search['MONTH'], df_btc_search['BTC_NEWS_SEARCH'], color='skyblue', linewidth=2, marker='o')
ax2.plot(df_btc_monthly['DATE'], df_btc_search['BTC_NEWS_SEARCH'], color='skyblue', linewidth=2, marker='o')
# ax1.plot(df_btc_monthly.index, df_btc_monthly['CLOSE'], color='orange', linewidth=2, linestyle='--')
# ax2.plot(df_btc_monthly.index, df_btc_search['BTC_NEWS_SEARCH'], color='skyblue', linewidth=2, marker='o')

ax1.set_xlim([df_btc_monthly['DATE'].min(), df_btc_search['MONTH'].max()])
ax1.set_ylabel('BTC Price', color='orange', fontsize=14)
# ax1.set_ylim([0, 15000])
ax1.set_ylim(bottom=0, top=15000)
# ax2.set_xlim([df_btc_monthly['DATE'].min(), df_btc_search['MONTH'].max()])
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

plt.show()

# df_btc_monthly.head()

# %%
# Were big increases in searches for Bitcoin accompanied by big increases in the 
# price?
# Yes.

# %% [markdown]
# ### Unemployement Benefits Search vs. Actual Unemployment in the U.S.

# %% [markdown]
# **Challenge** Plot the search for "unemployment benefits" against the unemployment rate.
# 1. Change the title to: Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate <br>
# 2. Change the y-axis label to: FRED U/E Rate <br>
# 3. Change the axis limits <br>
# 4. Add a grey [grid](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.grid.html) to the chart to better see the years and the U/E rate values. Use dashes for the line style<br>
# 5. Can you discern any seasonality in the searches? Is there a pattern?

# %%
# df_unemployment.head()

plt.figure(figsize=(14, 8), dpi=100)
# This overlays a grid of dashed lines
plt.grid(color='grey', alpha=0.2, linestyle='--')
# plt.grid(c='grey')
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate')

plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
ax2 = ax1.twinx()

# ax1.grid(color='grey', linestyle='--')
# # ax2.grid(color='grey', linestyle='--')

# format the ticks
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.plot(df_unemployment['MONTH'], df_unemployment['UNRATE'], color='purple', linewidth=2, linestyle='--')
ax2.plot(df_unemployment['MONTH'], df_unemployment['UE_BENEFITS_WEB_SEARCH'], color='skyblue', linewidth=2, linestyle='--')

# ax1.set_xlim([df_unemployment['MONTH'].min(), df_unemployment['MONTH'].max()])
ax1.set_xlim([df_unemployment.MONTH.min(), df_unemployment.MONTH.max()])
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=14)
# ax1.set_ylim([, ])
ax1.set_ylim(bottom=3, top=10.5)
# ax2.set_xlim([df_unemployment['MONTH'].min(), df_unemployment['MONTH'].max()])
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

plt.show()

# %%
# Can you discern any seasonality in the searches? Is there a pattern?

# %% [markdown]
# **Challenge**: Calculate the 3-month or 6-month rolling average for the web searches. Plot the 6-month rolling average search data against the actual unemployment. What do you see in the chart? Which line moves first?

# %%
roll_df = df_unemployment.rolling(window=3).mean()
roll_df
# Out:
#      UE_BENEFITS_WEB_SEARCH    UNRATE
# 0                       NaN       NaN
# 1                       NaN       NaN
# 2                 30.666667  5.700000
# 3                 29.000000  5.666667
# 4                 25.666667  5.666667
# ..                      ...       ...
# 176               14.666667  3.766667
# 177               14.333333  3.766667
# 178               15.000000  3.733333
# 179               16.000000  3.800000
# 180               18.000000  3.866667
#
# [181 rows x 2 columns]

# %%
roll_df = df_unemployment.rolling(window=6).mean()
roll_df
# Out:
#      UE_BENEFITS_WEB_SEARCH    UNRATE
# 0                       NaN       NaN
# 1                       NaN       NaN
# 2                       NaN       NaN
# 3                       NaN       NaN
# 4                       NaN       NaN
# ..                      ...       ...
# 176               14.833333  3.850000
# 177               14.666667  3.816667
# 178               15.000000  3.800000
# 179               15.333333  3.783333
# 180               16.166667  3.816667
#
# [181 rows x 2 columns]

# %%
roll_df = df_unemployment[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()
# roll_df

plt.figure(figsize=(14, 8), dpi=100)
plt.grid(color='grey', alpha=0.2, linestyle='--')
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate')

plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
ax2 = ax1.twinx()

# ax1.grid(color='grey', linestyle='--')
# # ax2.grid(color='grey', linestyle='--')

# format the ticks
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.plot(df_unemployment['MONTH'], roll_df['UNRATE'], color='purple', linewidth=2, linestyle='-.')
ax2.plot(df_unemployment['MONTH'], roll_df['UE_BENEFITS_WEB_SEARCH'], color='skyblue', linewidth=2, linestyle='-')

# ax1.set_xlim([df_unemployment['MONTH'].min(), df_unemployment['MONTH'].max()])
# # ax1.set_xlim([df_unemployment.MONTH.min(), df_unemployment.MONTH.max()])
ax1.set_xlim([df_unemployment.MONTH[0], df_unemployment.MONTH.max()])
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=14)
# ax1.set_ylim([3, 10.5])
ax1.set_ylim(bottom=3, top=10.5)
# ax2.set_xlim([roll_df['MONTH'].min(), roll_df['MONTH'].max()])
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

plt.show()

# %%
# What do you see in the chart? Which line moves first?
# We see that searches for "Unemployment Benefits" happen before the actual 
# official unemployment rate goes up. Similarly, the search popularity for the 
# term goes down before the unemployment rate decreases. In other words, these 
# searches seem to act as a leading economic indicator for the unemployment rate 
# (which is a lagging indicator).

# %% [markdown]
# ### Including 2020 in Unemployment Charts

# %% [markdown]
# **Challenge**: Read the data in the 'UE Benefits Search vs UE Rate 2004-20.csv' into a DataFrame. Convert the MONTH column to Pandas Datetime objects and then plot the chart. What do you see?

# %%
df_unemployment_new = pd.read_csv('./UE Benefits Search vs UE Rate 2004-20.csv')

# %%
df_unemployment_new.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                       9     5.7
# 1  2004-02                       8     5.6
# 2  2004-03                       7     5.8
# 3  2004-04                       8     5.6
# 4  2004-05                       6     5.6

# %%
df_unemployment_new.tail()
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 195  2020-04                     100    14.7
# 196  2020-05                      63    13.3
# 197  2020-06                      53    11.1
# 198  2020-07                      54    10.2
# 199  2020-08                      50     8.4

# %%
df_unemployment_new['MONTH'] = pd.to_datetime(df_unemployment_new.MONTH)

# %%
df_unemployment_new
# Out:
#          MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0   2004-01-01                       9     5.7
# 1   2004-02-01                       8     5.6
# 2   2004-03-01                       7     5.8
# 3   2004-04-01                       8     5.6
# 4   2004-05-01                       6     5.6
# ..         ...                     ...     ...
# 195 2020-04-01                     100    14.7
# 196 2020-05-01                      63    13.3
# 197 2020-06-01                      53    11.1
# 198 2020-07-01                      54    10.2
# 199 2020-08-01                      50     8.4
#
# [200 rows x 3 columns]

# %%
# roll_df = df_unemployment[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()
# # roll_df

plt.figure(figsize=(14, 8), dpi=100)
plt.grid(color='grey', alpha=0.2, linestyle='--')
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate incl 2020')

plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
ax2 = ax1.twinx()

# ax1.grid(color='grey', linestyle='--')
# # ax2.grid(color='grey', linestyle='--')

# format the ticks
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

# ax1.plot(df_unemployment_new['MONTH'], roll_df['UNRATE'], color='purple', linewidth=3)
# ax2.plot(df_unemployment-new['MONTH'], roll_df['UE_BENEFITS_WEB_SEARCH'], color='skyblue', linewidth=3)
ax1.plot(df_unemployment_new['MONTH'], df_unemployment_new['UNRATE'], color='purple', linewidth=3)
ax2.plot(df_unemployment_new['MONTH'], df_unemployment_new['UE_BENEFITS_WEB_SEARCH'], color='skyblue', linewidth=3)

ax1.set_xlim([df_unemployment_new.MONTH[0], df_unemployment_new.MONTH.max()])
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=14)
# ax1.set_ylim(bottom=3, top=20)  # <--- learned something new
# ax2.set_xlim([roll_df['MONTH'].min(), roll_df['MONTH'].max()])
# ax2.set_xlim([df_unemployment_new.MONTH[0], df_unemployment_new.MONTH.max()])
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

plt.show()

# %%
# What do you see?
